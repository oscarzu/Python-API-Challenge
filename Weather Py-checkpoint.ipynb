# %%
#Setting the dependencies and kpi Key
#If you havent install citypy don forget to run pip install citpy

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from citipy import citipy
import seaborn as sns

api_key="80fded64a8730f6431a58a549bf8890e"
#Range of latitudes and longitudes 
lat_range = (-10, 10)
lng_range = (-180, 180)

# %%
# List for lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
#Find cities near equator 
latitude = 0
cities = []
countries = []
columns = ['City', 'Country', 'Max Temperature', 'Humidity', 'Wind Speed', 'Cloudiness', 'Longitude', 'Latitude']

for longitude in range(-180,180): 
    city = citipy.nearest_city(latitude,longitude)
    cities.append(city.city_name)
    countries.append(city.country_code)
    
equatorial_cities = {'City': cities, 'Country': countries}

equatorial_cities_df=pd.DataFrame(equatorial_cities, columns=columns).drop_duplicates().reset_index(drop=True)
equatorial_cities_df.head()
# Out:
#          City Country Max Temperature Humidity Wind Speed Cloudiness  \
# 0     vaitupu      wf             NaN      NaN        NaN        NaN
# 1    saleaula      ws             NaN      NaN        NaN        NaN
# 2  samalaeulu      ws             NaN      NaN        NaN        NaN
# 3    lufilufi      ws             NaN      NaN        NaN        NaN
# 4      samusu      ws             NaN      NaN        NaN        NaN
#
#   Longitude Latitude
# 0       NaN      NaN
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      NaN
# 4       NaN      NaN

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather"
params = {"q":'', "APPID":api_key}
count=0
backup_weather_data=False

# Use iterrows to iterate through pandas dataframe
for index, row in equatorial_cities_df.iterrows():

   
    city_and_country = f"{row['City']},{row['Country']}"

    params['q'] = city_and_country
    
    try:
        response = requests.get(base_url, params=params).json()
        results  = response.get('cod')
        city     = response.get('name')
        
        if results == 200:
            sys     = response['sys']
            country = sys['country']
            weather_metrics = f"\n{city}, {country}: "
            
            main    = response['main']
            temp    = 9/5 * (float(main['temp_max']) - 273) + 32 # Convert Kelvin to Fahrenheit
            humid   = main['humidity']
            equatorial_cities_df.set_value(index, "Max Temperature", temp)
            equatorial_cities_df.set_value(index, "Humidity",        humid)
            weather_metrics += f"max temp: {temp} humidity: {humid} "
            
            wind    = response['wind']
            speed   = wind['speed']
            equatorial_cities_df.set_value(index, "Wind Speed", speed)
            weather_metrics += f"wind: {speed} "
            
            clouds  = response['clouds']
            clouds  = clouds['all']
            equatorial_cities_df.set_value(index, "Cloudiness", clouds)
            weather_metrics += f"clouds: {clouds} "
            
            coord   = response['coord']
            lon     = coord['lon']
            lat     = coord['lat']
            equatorial_cities_df.set_value(index, "Longitude", lon)
            equatorial_cities_df.set_value(index, "Latitude",  lat)
            weather_metrics += f"lon: {lon} lat: {lat} "
            
            print(weather_metrics)
            print('-' * 80)
            
        else:
            if count >= 60:
                print(response)
                backup_weather_data = True
                print('-' * 80)
                break
            count += 1            
            
    except:
        continue
# Out:
# C:\Users\zsantiba\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\zsantiba\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\zsantiba\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\zsantiba\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:38: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\zsantiba\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\zsantiba\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:45: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Lufilufi, WS: max temp: 75.27200000000005 humidity: 94 wind: 2.68 clouds: 100 lon: -171.6 lat: -13.87
# --------------------------------------------------------------------------------
#
# Faanui, PF: max temp: 77.9 humidity: 80 wind: 6.61 clouds: 0 lon: -151.75 lat: -16.48
# --------------------------------------------------------------------------------
#
# Atuona, PF: max temp: 79.98800000000006 humidity: 77 wind: 7.284 clouds: 68 lon: -139.03 lat: -9.8
# --------------------------------------------------------------------------------
#
# San Patricio, MX: max temp: 89.86999999999996 humidity: 70 wind: 7.7 clouds: 20 lon: -104.7 lat: 19.22
# --------------------------------------------------------------------------------
#
# Coahuayana, MX: max temp: 86.61199999999997 humidity: 68 wind: 0.628 clouds: 80 lon: -100.35 lat: 18.62
# --------------------------------------------------------------------------------
#
# Lazaro Cardenas, MX: max temp: 75.27200000000005 humidity: 64 wind: 5.1 clouds: 75 lon: -105.62 lat: 28.39
# --------------------------------------------------------------------------------
#
# Ixtapa, MX: max temp: 89.27599999999998 humidity: 70 wind: 3.6 clouds: 20 lon: -105.21 lat: 20.71
# --------------------------------------------------------------------------------
#
# Puerto Ayora, EC: max temp: 77.26999999999995 humidity: 61 wind: 10.3 clouds: 75 lon: -90.35 lat: -0.74
# --------------------------------------------------------------------------------
#
# San Cristobal, EC: max temp: 89.49199999999999 humidity: 47 wind: 1.61 clouds: 71 lon: -79.44 lat: -1.02
# --------------------------------------------------------------------------------
#
# Manta, EC: max temp: 79.06999999999996 humidity: 78 wind: 6.2 clouds: 20 lon: -80.73 lat: -0.95
# --------------------------------------------------------------------------------
#
# Bahia de Caraquez, EC: max temp: 79.06999999999996 humidity: 78 wind: 6.2 clouds: 20 lon: -80.42 lat: -0.6
# --------------------------------------------------------------------------------
#
# Pedernales, EC: max temp: 75.29000000000002 humidity: 80 wind: 3.248 clouds: 63 lon: -80.05 lat: 0.07
# --------------------------------------------------------------------------------
#
# Santo Domingo, EC: max temp: 86.26999999999995 humidity: 55 wind: 3.6 clouds: 40 lon: -80.3 lat: -2.48
# --------------------------------------------------------------------------------
#
# Cayambe, EC: max temp: 68.26999999999995 humidity: 52 wind: 8.7 clouds: 40 lon: -78.14 lat: 0.04
# --------------------------------------------------------------------------------
#
# Nueva Loja, EC: max temp: 86.26999999999995 humidity: 66 wind: 2.1 clouds: 40 lon: -76.88 lat: 0.08
# --------------------------------------------------------------------------------
#
# Puerto Asis, CO: max temp: 84.46999999999997 humidity: 70 wind: 1.5 clouds: 20 lon: -76.5 lat: 0.51
# --------------------------------------------------------------------------------
#
# Puerto Leguizamo, CO: max temp: 87.15199999999999 humidity: 58 wind: 1.69 clouds: 100 lon: -74.78 lat: -0.19
# --------------------------------------------------------------------------------
#
# Miraflores, CO: max temp: 73.32799999999997 humidity: 83 wind: 1.056 clouds: 75 lon: -73.14 lat: 5.2
# --------------------------------------------------------------------------------
#
# Mitu, CO: max temp: 85.424 humidity: 63 wind: 0.932 clouds: 89 lon: -70.17 lat: 1.2
# --------------------------------------------------------------------------------
#
# Sao Gabriel da Cachoeira, BR: max temp: 84.46999999999997 humidity: 74 wind: 3.6 clouds: 40 lon: -67.09 lat: -0.13
# --------------------------------------------------------------------------------
#
# Santa Isabel do Rio Negro, BR: max temp: 89.85199999999998 humidity: 58 wind: 0.879 clouds: 82 lon: -65.02 lat: -0.41
# --------------------------------------------------------------------------------
#
# Barcelos, BR: max temp: 83.01199999999996 humidity: 74 wind: 2.985 clouds: 27 lon: -62.93 lat: -0.97
# --------------------------------------------------------------------------------
#
# Boa Vista, BR: max temp: 93.46999999999997 humidity: 44 wind: 4.1 clouds: 40 lon: -60.67 lat: 2.82
# --------------------------------------------------------------------------------
#
# Urucara, BR: max temp: 90.48200000000003 humidity: 47 wind: 0.733 clouds: 90 lon: -57.76 lat: -2.54
# --------------------------------------------------------------------------------
#
# Oriximina, BR: max temp: 94.83800000000005 humidity: 40 wind: 3.253 clouds: 0 lon: -55.87 lat: -1.77
# --------------------------------------------------------------------------------
#
# Alenquer, BR: max temp: 89.86999999999996 humidity: 59 wind: 3.1 clouds: 20 lon: -54.74 lat: -1.95
# --------------------------------------------------------------------------------
#
# Prainha, BR: max temp: 94.35199999999998 humidity: 37 wind: 1.916 clouds: 57 lon: -53.48 lat: -1.8
# --------------------------------------------------------------------------------
#
# Almeirim, BR: max temp: 91.72400000000002 humidity: 48 wind: 2.774 clouds: 89 lon: -52.58 lat: -1.53
# --------------------------------------------------------------------------------
#
# Mazagao, BR: max temp: 89.86999999999996 humidity: 55 wind: 6.2 clouds: 20 lon: -51.29 lat: -0.12
# --------------------------------------------------------------------------------
#
# Macapa, BR: max temp: 89.86999999999996 humidity: 55 wind: 6.2 clouds: 20 lon: -51.07 lat: 0.05
# --------------------------------------------------------------------------------
#
# Soure, BR: max temp: 82.52599999999998 humidity: 70 wind: 6.024 clouds: 57 lon: -48.52 lat: -0.72
# --------------------------------------------------------------------------------
#
# Curuca, BR: max temp: 85.78399999999999 humidity: 70 wind: 2.465 clouds: 100 lon: -61.06 lat: -2.52
# --------------------------------------------------------------------------------
#
# Salinopolis, BR: max temp: 82.184 humidity: 79 wind: 9.732 clouds: 43 lon: -47.36 lat: -0.61
# --------------------------------------------------------------------------------
#
# Viseu, BR: max temp: 81.68000000000004 humidity: 78 wind: 8.756 clouds: 18 lon: -46.14 lat: -1.2
# --------------------------------------------------------------------------------
#
# Carutapera, BR: max temp: 81.68000000000004 humidity: 78 wind: 8.756 clouds: 18 lon: -46.02 lat: -1.2
# --------------------------------------------------------------------------------
#
# Cururupu, BR: max temp: 79.71799999999999 humidity: 72 wind: 2.191 clouds: 3 lon: -44.87 lat: -1.82
# --------------------------------------------------------------------------------
#
# Tutoia, BR: max temp: 84.46999999999997 humidity: 74 wind: 9.8 clouds: 20 lon: -42.27 lat: -2.76
# --------------------------------------------------------------------------------
#
# Camocim, BR: max temp: 88.06999999999996 humidity: 58 wind: 10.3 clouds: 20 lon: -40.84 lat: -2.9
# --------------------------------------------------------------------------------
#
# Itarema, BR: max temp: 88.06999999999996 humidity: 58 wind: 10.3 clouds: 20 lon: -39.92 lat: -2.92
# --------------------------------------------------------------------------------
#
# Paracuru, BR: max temp: 82.66999999999996 humidity: 65 wind: 5.7 clouds: 28 lon: -39.03 lat: -3.41
# --------------------------------------------------------------------------------
#
# Caucaia, BR: max temp: 82.66999999999996 humidity: 65 wind: 5.7 clouds: 9 lon: -38.66 lat: -3.73
# --------------------------------------------------------------------------------
#
# Aquiraz, BR: max temp: 82.66999999999996 humidity: 65 wind: 5.7 clouds: 17 lon: -38.39 lat: -3.9
# --------------------------------------------------------------------------------
#
# Touros, BR: max temp: 79.06999999999996 humidity: 74 wind: 5.1 clouds: 20 lon: -35.46 lat: -5.2
# --------------------------------------------------------------------------------
#
# Georgetown, SH: max temp: 74.49800000000002 humidity: 81 wind: 7.383 clouds: 100 lon: -14.42 lat: -7.93
# --------------------------------------------------------------------------------
#
# Monrovia, LR: max temp: 77.26999999999995 humidity: 94 wind: 3.039 clouds: 75 lon: -10.8 lat: 6.33
# --------------------------------------------------------------------------------
# Buchanan, LR: max temp: 77.26999999999995 humidity: 94 wind: 1.5 clouds: 75 lon: -10.05 lat: 5.88
# --------------------------------------------------------------------------------
#
# Harper, LR: max temp: 73.92200000000004 humidity: 94 wind: 1.306 clouds: 87 lon: -7.71 lat: 4.38
# --------------------------------------------------------------------------------
#
# Tabou, CI: max temp: 73.92200000000004 humidity: 94 wind: 1.306 clouds: 87 lon: -7.36 lat: 4.42
# --------------------------------------------------------------------------------
#
# Axim, GH: max temp: 75.74000000000002 humidity: 93 wind: 2.254 clouds: 50 lon: -2.24 lat: 4.87
# --------------------------------------------------------------------------------
#
# Takoradi, GH: max temp: 78.13399999999999 humidity: 89 wind: 5.28 clouds: 78 lon: -1.75 lat: 4.89
# --------------------------------------------------------------------------------
#
# Mumford, GH: max temp: 74.62400000000002 humidity: 96 wind: 2.317 clouds: 38 lon: -0.76 lat: 5.26
# --------------------------------------------------------------------------------
#
# Anloga, GH: max temp: 80.86999999999996 humidity: 88 wind: 5.1 clouds: 20 lon: 0.9 lat: 5.79
# --------------------------------------------------------------------------------
#
# Port-Gentil, GA: max temp: 75.46999999999997 humidity: 100 wind: 3.6 clouds: 40 lon: 8.78 lat: -0.72
# --------------------------------------------------------------------------------
#
# Libreville, GA: max temp: 77.26999999999995 humidity: 88 wind: 5.1 clouds: 40 lon: 9.45 lat: 0.39
# --------------------------------------------------------------------------------
#
# Kango, GA: max temp: 70.98800000000006 humidity: 98 wind: 0.833 clouds: 100 lon: 10.1 lat: 0.19
# --------------------------------------------------------------------------------
#
# Ndjole, GA: max temp: 71.834 humidity: 96 wind: 1.484 clouds: 100 lon: 10.76 lat: -0.18
# --------------------------------------------------------------------------------
#
# Booue, GA: max temp: 70.60999999999999 humidity: 98 wind: 1.038 clouds: 100 lon: 11.94 lat: -0.09
# --------------------------------------------------------------------------------
#
# Makokou, GA: max temp: 70.37599999999999 humidity: 98 wind: 2.061 clouds: 100 lon: 12.85 lat: 0.56
# --------------------------------------------------------------------------------
#
# Ewo, CG: max temp: 72.01400000000004 humidity: 93 wind: 1.469 clouds: 68 lon: 14.81 lat: -0.88
# --------------------------------------------------------------------------------
#
# Owando, CG: max temp: 72.03200000000001 humidity: 96 wind: 1.39 clouds: 95 lon: 15.91 lat: -0.49
# --------------------------------------------------------------------------------
#
# Mbandaka, CD: max temp: 74.11999999999996 humidity: 81 wind: 0.796 clouds: 0 lon: 18.26 lat: 0.05
# --------------------------------------------------------------------------------
#
# Boende, CD: max temp: 73.09399999999997 humidity: 84 wind: 0.763 clouds: 0 lon: 20.88 lat: -0.28
# --------------------------------------------------------------------------------
#
# Basoko, CD: max temp: 71.27599999999998 humidity: 88 wind: 0.082 clouds: 100 lon: 23.61 lat: 1.23
# --------------------------------------------------------------------------------
#
# Yangambi, CD: max temp: 71.90600000000003 humidity: 92 wind: 0.688 clouds: 39 lon: 24.47 lat: 0.77
# --------------------------------------------------------------------------------
#
# Kisangani, CD: max temp: 72.93200000000002 humidity: 87 wind: 0.043 clouds: 61 lon: 25.21 lat: 0.52
# --------------------------------------------------------------------------------
#
# Butembo, CD: max temp: 60.25999999999998 humidity: 90 wind: 1.663 clouds: 55 lon: 29.29 lat: 0.12
# --------------------------------------------------------------------------------
#
# Kilembe, UG: max temp: 64.81400000000004 humidity: 90 wind: 1.111 clouds: 59 lon: 30.01 lat: 0.2
# --------------------------------------------------------------------------------
#
# Lyantonde, UG: max temp: 63.95 humidity: 89 wind: 0.965 clouds: 100 lon: 31.15 lat: -0.41
# --------------------------------------------------------------------------------
#
# Lukaya, UG: max temp: 68.26999999999995 humidity: 94 wind: 1.5 clouds: 20 lon: 31.87 lat: -0.15
# --------------------------------------------------------------------------------
#
# Lugazi, UG: max temp: 68.26999999999995 humidity: 94 wind: 1.5 clouds: 20 lon: 32.94 lat: 0.37
# --------------------------------------------------------------------------------
#
# Ahero, KE: max temp: 68.26999999999995 humidity: 88 wind: 1.766 clouds: 75 lon: 34.92 lat: -0.17
# --------------------------------------------------------------------------------
#
# Rongai, KE: max temp: 65.35399999999996 humidity: 74 wind: 0.288 clouds: 66 lon: 35.86 lat: -0.17
# --------------------------------------------------------------------------------
#
# Nanyuki, KE: max temp: 58.53200000000002 humidity: 91 wind: 3.49 clouds: 36 lon: 37.07 lat: 0.01
# --------------------------------------------------------------------------------
#
# Maua, KE: max temp: 76.1 humidity: 69 wind: 0.974 clouds: 82 lon: 37.94 lat: 0.23
# --------------------------------------------------------------------------------
#
# Garissa, KE: max temp: 78.566 humidity: 70 wind: 6.969 clouds: 0 lon: 39.64 lat: -0.46
# --------------------------------------------------------------------------------
#
# Jamame, SO: max temp: 80.16799999999998 humidity: 84 wind: 6.849 clouds: 100 lon: 42.75 lat: 0.07
# --------------------------------------------------------------------------------
#
# Mogadishu, SO: max temp: 80.33000000000004 humidity: 85 wind: 5.892 clouds: 10 lon: 45.34 lat: 2.04
# --------------------------------------------------------------------------------
#
# Hobyo, SO: max temp: 80.16799999999998 humidity: 78 wind: 4.502 clouds: 14 lon: 48.53 lat: 5.35
# --------------------------------------------------------------------------------
#
# Victoria, SC: max temp: 77.26999999999995 humidity: 88 wind: 1.5 clouds: 40 lon: 55.45 lat: -4.62
# --------------------------------------------------------------------------------
#
# Thinadhoo, MV: max temp: 81.10399999999996 humidity: 81 wind: 6.341 clouds: 92 lon: 72.93 lat: 0.53
# --------------------------------------------------------------------------------
#
# Matara, LK: max temp: 77.32400000000001 humidity: 87 wind: 0.765 clouds: 100 lon: 80.54 lat: 5.95
# --------------------------------------------------------------------------------
#
# Hambantota, LK: max temp: 82.21999999999997 humidity: 74 wind: 1.025 clouds: 100 lon: 81.12 lat: 6.12
# --------------------------------------------------------------------------------
#
# Meulaboh, ID: max temp: 77.95399999999995 humidity: 84 wind: 3.645 clouds: 100 lon: 96.13 lat: 4.14
# --------------------------------------------------------------------------------
#
# Sibolga, ID: max temp: 70.28599999999997 humidity: 96 wind: 0.917 clouds: 100 lon: 98.78 lat: 1.74
# --------------------------------------------------------------------------------
#
# Payakumbuh, ID: max temp: 65.28200000000001 humidity: 93 wind: 0.58 clouds: 91 lon: 100.63 lat: -0.23
# --------------------------------------------------------------------------------
#
# Sijunjung, ID: max temp: 68.41400000000004 humidity: 95 wind: 0.458 clouds: 88 lon: 100.95 lat: -0.69
# --------------------------------------------------------------------------------
#
# Kijang, ID: max temp: 77.26999999999995 humidity: 94 wind: 0.942 clouds: 32 lon: 104.63 lat: 0.9
# --------------------------------------------------------------------------------
#
# Sungairaya, ID: max temp: 74.80399999999995 humidity: 90 wind: 0.999 clouds: 59 lon: 108.9 lat: 0.7
# --------------------------------------------------------------------------------
#
# Pontianak, ID: max temp: 73.47200000000004 humidity: 95 wind: 0.377 clouds: 75 lon: 109.34 lat: -0.02
# --------------------------------------------------------------------------------
#
# Sri Aman, MY: max temp: 73.66999999999996 humidity: 100 wind: 0.354 clouds: 90 lon: 111.46 lat: 1.24
# --------------------------------------------------------------------------------
#
# Kapit, MY: max temp: 71.00600000000003 humidity: 99 wind: 0.355 clouds: 82 lon: 112.94 lat: 2.02
# --------------------------------------------------------------------------------
# Loa Janan, ID: max temp: 73.79600000000005 humidity: 96 wind: 0.298 clouds: 6 lon: 117.09 lat: -0.58
# --------------------------------------------------------------------------------
#
# Bontang, ID: max temp: 81.06799999999998 humidity: 77 wind: 0.778 clouds: 42 lon: 117.47 lat: 0.12
# --------------------------------------------------------------------------------
#
# Palu, ID: max temp: 66.34399999999997 humidity: 96 wind: 1.086 clouds: 97 lon: 119.87 lat: -0.9
# --------------------------------------------------------------------------------
#
# Poso, ID: max temp: 66.66799999999998 humidity: 87 wind: 1.567 clouds: 8 lon: 120.75 lat: -1.4
# --------------------------------------------------------------------------------
#
# Gorontalo, ID: max temp: 72.96799999999999 humidity: 92 wind: 1.219 clouds: 30 lon: 123.06 lat: 0.54
# --------------------------------------------------------------------------------
#
# Tondano, ID: max temp: 71.6 humidity: 89 wind: 0.484 clouds: 24 lon: 124.91 lat: 1.3
# --------------------------------------------------------------------------------
#
# Sorong, ID: max temp: 71.834 humidity: 98 wind: 0.636 clouds: 73 lon: 131.25 lat: -0.86
# --------------------------------------------------------------------------------
#
# Manokwari, ID: max temp: 73.13000000000005 humidity: 79 wind: 2.293 clouds: 96 lon: 134.08 lat: -0.87
# --------------------------------------------------------------------------------
#
# Biak, ID: max temp: 80.86999999999996 humidity: 80 wind: 3.648 clouds: 100 lon: 122.88 lat: -0.91
# --------------------------------------------------------------------------------
#
# Vanimo, PG: max temp: 80.47400000000002 humidity: 75 wind: 3.187 clouds: 99 lon: 141.3 lat: -2.67
# --------------------------------------------------------------------------------
#
# Aitape, PG: max temp: 80.726 humidity: 70 wind: 2.441 clouds: 79 lon: 142.36 lat: -3.15
# --------------------------------------------------------------------------------
#
# Lorengau, PG: max temp: 84.01999999999995 humidity: 72 wind: 3.821 clouds: 100 lon: 147.27 lat: -2.02
# --------------------------------------------------------------------------------
#
# Kavieng, PG: max temp: 83.04800000000003 humidity: 70 wind: 1.222 clouds: 33 lon: 150.8 lat: -2.57
# --------------------------------------------------------------------------------
#
# Namatanai, PG: max temp: 81.33800000000005 humidity: 79 wind: 2.507 clouds: 98 lon: 152.44 lat: -3.66
# --------------------------------------------------------------------------------
#
# Kieta, PG: max temp: 80.18599999999998 humidity: 75 wind: 1.778 clouds: 98 lon: 155.63 lat: -6.22
# --------------------------------------------------------------------------------
#
# Buala, SB: max temp: 80.85199999999998 humidity: 78 wind: 2.102 clouds: 100 lon: 159.59 lat: -8.15
# --------------------------------------------------------------------------------

# %%
equatorial_cities_df = equatorial_cities_df.dropna(axis=0, how='any').reset_index(drop=True)

equatorial_cities_df.to_csv('cities.csv', index=False)

date = time.strftime("%m/%d/%Y")

if backup_weather_data:
    equatorial_cities_df = pd.read_csv('cities.csv')
    date = '10/10/2019'
    
print(f"There are {equatorial_cities_df.shape[0]} equatorial cities with weather data available in dataframe.")
equatorial_cities_df.head()
# Out:
# There are 107 equatorial cities with weather data available in dataframe.
#            City Country Max Temperature Humidity Wind Speed Cloudiness  \
# 0      lufilufi      ws          75.272       94       2.68        100
# 1        faanui      pf            77.9       80       6.61          0
# 2        atuona      pf          79.988       77      7.284         68
# 3  san patricio      mx           89.87       70        7.7         20
# 4    coahuayana      mx          86.612       68      0.628         80
#
#   Longitude Latitude
# 0    -171.6   -13.87
# 1   -151.75   -16.48
# 2   -139.03     -9.8
# 3    -104.7    19.22
# 4   -100.35    18.62

# %%
def create_scatter(data, **kwargs):
    
        sns.set() # sets seaborn grid
        sns.lmplot(x=kwargs['xdata'], y=kwargs['ydata'], data=data, fit_reg=False, legend_out=False)

        plt.title(kwargs['title'])
        plt.xlabel(kwargs['xlabel'])
        plt.ylabel(kwargs['ylabel'])

        plt.show()

# %%
title  = f'City Latitude v. Max Temperature ({date})'
xlabel = 'Latitude'
ylabel = 'Max Temperature (F)'
xdata  = 'Latitude'
ydata  = 'Max Temperature'
alpha=.80

create_scatter(data=equatorial_cities_df, title=title, xlabel=xlabel, ylabel=ylabel, xdata=xdata, ydata=ydata)

# %%
title  = f'City Latitude v. Humidity ({date})'
xlabel = 'Latitude'
ylabel = 'Humidity (%)'
xdata  = 'Latitude'
ydata  = 'Humidity'
alpha=.80

create_scatter(data=equatorial_cities_df, title=title, xlabel=xlabel, ylabel=ylabel, xdata=xdata, ydata=ydata)

# %%
title  = f'City Latitude v. Cloudiness ({date})'
xlabel = 'Latitude'
ylabel = 'Cloudiness (%)'
xdata  = 'Latitude'
ydata  = 'Cloudiness'
alpha=.80

create_scatter(data=equatorial_cities_df, title=title, xlabel=xlabel, ylabel=ylabel, xdata=xdata, ydata=ydata)

# %%
title  = f'City Latitude v. Wind Speed ({date})'
xlabel = 'Latitude'
ylabel = 'Wind Speed (MPH)'
xdata  = 'Latitude'
ydata  = 'Wind Speed'
alpha=.80

create_scatter(data=equatorial_cities_df, title=title, xlabel=xlabel, ylabel=ylabel, xdata=xdata, ydata=ydata)

# %%
#Analysis
#Max temperatures are observed to be most frequent at or near the equator. 
#High percentage of humidity is associated with regions at or within 10 degrees of the equator. 
#Cities 10 degrees from the equator are more likely to hve Wind Speeds greater than 5 MPH
